# %% [markdown]
# <a href="https://colab.research.google.com/github/Kirankavala143/Fmml-assignment/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 05:33:49--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   186MB/s    in 0.4s
#
# 2024-03-31 05:33:49 (186 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 27348  1703.04062v1  This paper presents a multi-pose face recognit...    cs
# 39841  1706.03220v1  Present image based visual servoing approaches...    cs
# 15823  1605.08675v1  In this paper an open-domain factoid question ...    cs
# 23958   1309.5594v2  The main finding of this work is that the stan...    cs
# 22693  1704.06735v3  Gaussian processes (GPs) are powerful non-para...  stat
# ...             ...                                                ...   ...
# 519    1505.08075v1  We propose a technique for learning representa...    cs
# 40371   0705.2318v1  We analyze the generalization performance of a...    cs
# 19976   1303.5730v1  This paper outlines a methodology for analyzin...    cs
# 12463  1802.03840v1  Exploratory data analysis is a crucial task fo...  stat
# 7265   1711.05560v1  We present the Variational Adaptive Newton (VA...  stat
#
#                                                    title  year  \
# 27348  Multi-Pose Face Recognition Using Hybrid Face ...  2017
# 39841  Exploring Convolutional Networks for End-to-En...  2017
# 15823  Boosting Question Answering by Deep Entity Rec...  2016
# 23958  Generic Image Classification Approaches Excel ...  2013
# 22693  Asynchronous Distributed Variational Gaussian ...  2017
# ...                                                  ...   ...
# 519    Transition-Based Dependency Parsing with Stack...  2015
# 40371  Statistical Mechanics of Nonlinear On-line Lea...  2007
# 19976  Representation Requirements for Supporting Dec...  2013
# 12463  Uncharted Forest a Technique for Exploratory D...  2018
# 7265   Variational Adaptive-Newton Method for Explora...  2017
#
#                                                 keywords
# 27348  [recognition, descriptors, descriptor, contain...
# 39841  [approaches, extracting, important, performanc...
# 15823  [answering, presented, answering, correspondin...
# 23958  [classification, dictionary, classification, o...
# 22693  [processes, parametric, estimators, applicatio...
# ...                                                  ...
# 519    [technique, representations, transition, depen...
# 40371  [generalization, performance, nonlinear, perce...
# 19976  [methodology, analyzing, representational, kno...
# 12463  [exploratory, developing, effective, classific...
# 7265   [variational, optimization, especially, explor...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 27348    [recognition, descriptors, descriptor, contain...
# 39841    [approaches, extracting, important, performanc...
# 15823    [answering, presented, answering, correspondin...
# 23958    [classification, dictionary, classification, o...
# 22693    [processes, parametric, estimators, applicatio...
#                                ...
# 6688     [interpreting, challenging, framework, detecti...
# 14776    [prominent, processing, probabilistic, develop...
# 15070    [significant, especially, referring, phenomeno...
# 35995    [constraint, propagation, techniques, constrai...
# 7429     [intelligence, techniques, developed, essentia...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8726 words.
# Out of those 4551 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="7d470a0c-344a-4f83-acf9-730d02c412e8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7d470a0c-344a-4f83-acf9-730d02c412e8")) {                    Plotly.newPlot(                        "7d470a0c-344a-4f83-acf9-730d02c412e8",                        [{"x":["discriminant","containing","sufficiently","variability","recognition","performance","different","component","extracted","information","frequency","represent","achievement","reasonable","descriptors","descriptor","variations","quadrotor","demonstrate","approaches","experiments","unstructured","localization","performed","motivated","simulation","robustness","environments","representations","parameters","extracting","breakthroughs","convolutional","knowledge","important","available","exploring","implemented","previously","technique","answering","traditional","sentences","disambiguation","references","evaluation","wikipedia","solutions","assembled","retrieving","presented","including","comprehensive","automatic","constraints","categories","analysing","essential","introduced","questions","corresponding","dictionaries","surprising","promising","particular","literature","challenging","respectively","accuracies","prominent","algorithms","dictionary","outperforms","benchmark","developing","classification","estimators","framework","efficient","distributed","inference","processes","comparable","maintaining","stochastic","applications","application","implements","alleviated","predictive","efficiency","excellent","magnitudes","regression","inferences","synchronous","augmentation","procedures","variational","optimization","asynchronous","computational","prediction","expensive","parametric","satisfactory","researchers","consuming","discovery","systematic","generated","electronic","reviewing","documents","magnitude","techniques","endpoints","extraction","objective","degeneration","implications","validation","specificity","diagnosis","determine","classifying","coherence","sensitivity","effective","datapoints","categorize","represents","utilizing","independent","opportunity","tomography","ophthalmology","conclusions","distinguish","constructed","screening","databases","automated","detection","separated","clustering","objectives","supervised","adaptively","parameterizes","normalized","synthetic","unsupervised","unbalanced","theoretically","naturally","selection","modulating","partitioning","sensitive","superiority","classifier","ensembles","effectiveness","recursively","investigate","collection","sophisticated","published","structure","decomposing","radiology","multilingual","annotator","translates","translating","developed","interpretability","uncertainty","probabilistic","aleatoric","increases","illustrate","usefulness","epistemic","variables","guidelines","embedding","inspiration","practical","fundamental","processing","development","relationship","construction","recursive","drawbacks","generating","representation","designing"],"y":[16,58,23,31,376,948,750,113,108,729,56,111,3,37,48,29,87,3,562,441,582,24,62,134,47,72,109,92,212,256,65,7,384,361,352,305,38,96,108,239,51,173,75,14,5,245,26,144,4,11,170,263,59,169,159,75,11,73,138,57,127,19,9,106,269,117,257,88,23,26,606,52,252,207,68,480,18,548,394,79,208,94,85,31,133,445,242,16,3,64,159,32,4,106,13,5,23,38,51,341,16,277,214,54,41,18,67,36,52,33,162,17,6,68,60,382,1,150,186,2,30,49,12,56,77,49,19,34,259,2,11,41,38,141,10,19,2,21,31,66,12,57,94,372,14,126,37,215,23,0,25,143,153,2,45,60,182,0,11,70,35,147,22,221,10,137,63,25,41,317,6,3,21,10,7,16,204,12,70,145,0,50,75,26,6,121,8,126,6,143,92,271,113,71,71,24,20,95,357,36],"type":"bar"},{"x":["discriminant","containing","sufficiently","variability","recognition","performance","different ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4551,), (4551, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.78

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.12695590327169273)
# 	architecture (0.0821479374110953)
# 	knowledge (0.12837837837837837)
# 	segmentation (0.0732574679943101)
# 	experimental (0.14046941678520625)
# 	information (0.2592460881934566)
# 	detection (0.13229018492176386)
# 	different (0.26671408250355616)
# 	convolutional (0.13655761024182078)
# 	recognition (0.1337126600284495)
#
# Some Statistics words are:
# 	algorithm (0.38380281690140844)
# 	stochastic (0.13933601609657947)
# 	theoretical (0.15392354124748492)
# 	estimation (0.17303822937625754)
# 	distribution (0.18108651911468812)
# 	statistical (0.16146881287726358)
# 	variables (0.15442655935613683)
# 	inference (0.193158953722334)
# 	dimensional (0.19064386317907445)
# 	regression (0.18259557344064387)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="748abceb-b40a-418a-a5e6-016c60a45a54" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("748abceb-b40a-418a-a5e6-016c60a45a54")) {                    Plotly.newPlot(                        "748abceb-b40a-418a-a5e6-016c60a45a54",                        [{"x":["discriminant","containing","sufficiently","variability","recognition","performance","different","component","extracted","information","frequency","represent","achievement","reasonable","descriptors","descriptor","variations","quadrotor","demonstrate","approaches","experiments","unstructured","localization","performed","motivated","simulation","robustness","environments","representations","parameters","extracting","breakthroughs","convolutional","knowledge","important","available","exploring","implemented","previously","technique","answering","traditional","sentences","disambiguation","references","evaluation","wikipedia","solutions","assembled","retrieving","presented","including","comprehensive","automatic","constraints","categories","analysing","essential","introduced","questions","corresponding","dictionaries","surprising","promising","particular","literature","challenging","respectively","accuracies","prominent","algorithms","dictionary","outperforms","benchmark","developing","classification","estimators","framework","efficient","distributed","inference","processes","comparable","maintaining","stochastic","applications","application","implements","alleviated","predictive","efficiency","excellent","magnitudes","regression","inferences","synchronous","augmentation","procedures","variational","optimization","asynchronous","computational","prediction","expensive","parametric","satisfactory","researchers","consuming","discovery","systematic","generated","electronic","reviewing","documents","magnitude","techniques","endpoints","extraction","objective","degeneration","implications","validation","specificity","diagnosis","determine","classifying","coherence","sensitivity","effective","datapoints","categorize","represents","utilizing","independent","opportunity","tomography","ophthalmology","conclusions","distinguish","constructed","screening","databases","automated","detection","separated","clustering","objectives","supervised","adaptively","parameterizes","normalized","synthetic","unsupervised","unbalanced","theoretically","naturally","selection","modulating","partitioning","sensitive","superiority","classifier","ensembles","effectiveness","recursively","investigate","collection","sophisticated","published","structure","decomposing","radiology","multilingual","annotator","translates","translating","developed","interpretability","uncertainty","probabilistic","aleatoric","increases","illustrate","usefulness","epistemic","variables","guidelines","embedding","inspiration","practical","fundamental","processing","development","relationship","construction","recursive","drawbacks","generating","representation","designing","parameter","engineering","comparisons","recurrent","embeddings","character","introduce","microwave","interactions","collecting","unlabeled","thousands","properties","temperature","generative","communication","incorporate","household","conducted","adversarial","opportunities","classifiers","difficult","challenges","recognize","generalization","measurements","recognizing","visualization","synthesizing","directions","analytics","reasoning","combination","analytical","integrating","highlighting","impactful","interactive","approximated","simulations","achieving","eigenvector","favorably","algorithm","statistical","formulate","programming","integrates","permissible","rotations","establishing","procedure","theoretical","synchronization","instantiations","semidefinit ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	parameterizes
# 	modulating
# 	aleatoric
# 	confounded
# 	reminiscent
# 	integrable
# 	preventive
# 	blockmodel
# 	econometrics
# 	preselected
# 	covariates
# 	bernstein
# 	semiparametric
# 	homomorphic
# 	encrypted
# 	radiographs
# 	dendrogram
# 	customization
# 	periodicity
# 	beginnings
# Some words which never appear in Statistics papers:
# 	achievement
# 	quadrotor
# 	disambiguation
# 	assembled
# 	radiology
# 	household
# 	quantifier
# 	malignant
# 	watershed
# 	radiologist
# 	sensitivities
# 	ontologies
# 	monocular
# 	stereoscopic
# 	monolingual
# 	activitynet
# 	container
# 	ultrasound
# 	watermarked
# 	authentication

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0608184628569685e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.735
